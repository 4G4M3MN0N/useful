# %%
from atlassian import Confluence

# %%
confluence = Confluence(
    url='http://localhost:8080',
    username='mike.hamilton@enginegroup.com',
    password='')

# %%
help(confluence)
# Out:
# Help on Confluence in module atlassian.confluence object:
#
# class Confluence(atlassian.rest_client.AtlassianRestAPI)
#  |  Confluence(url, username=None, password=None, timeout=60, api_root='rest/api', api_version='latest', verify_ssl=True, session=None, oauth=None, cookies=None, advanced_mode=None, kerberos=None)
#  |
#  |  Method resolution order:
#  |      Confluence
#  |      atlassian.rest_client.AtlassianRestAPI
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  add_comment(self, page_id, text)
#  |      Add comment into page
#  |      :param page_id
#  |      :param text
#  |
#  |  add_user_to_group(self, username, group_name)
#  |      Add given user to a group
#  |
#  |      :param username: str
#  |      :param group_name: str
#  |      :return: Current state of the group
#  |
#  |  anonymous(self)
#  |      Get information about the how anonymous is represented in confluence
#  |      :return:
#  |
# ...

# %%
cnf = confluence

# %%
dir(cnf)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_create_basic_session',
#  '_create_body',
#  '_create_kerberos_session',
#  '_create_oauth_session',
#  '_session',
#  '_update_header',
#  'add_comment',
#  'add_user_to_group',
#  'advanced_mode',
#  'anonymous',
#  'api_root',
#  'api_version',
#  'append_page',
#  'attach_content',
#  'attach_file',
#  'audit',
#  'avatar_set_default_for_user',
#  'avatar_upload_for_user',
#  'check_access_mode',
#  'check_long_task_result',
#  'check_long_tasks_result',
#  'clean_all_caches',
#  'clean_package_cache',
#  'content_types',
#  'convert_storage_to_view',
# ...

# %%
help(cnf.get_page_by_title)
# Out:
# Help on method get_page_by_title in module atlassian.confluence:
#
# get_page_by_title(space, title, start=0, limit=1, expand=None) method of atlassian.confluence.Confluence instance
#     Returns the first page  on a piece of Content.
#     :param space: Space key
#     :param title: Title of the page
#     :param start: OPTIONAL: The start point of the collection to return. Default: None (0).
#     :param limit: OPTIONAL: The limit of the number of labels to return, this may be restricted by
#                         fixed system limits. Default: 1.
#     :param expand: OPTIONAL: expand e.g. history
#     :return: The JSON data returned from searched results the content endpoint, or the results of the
#              callback. Will raise requests.HTTPError on bad input, potentially.
#              If it has IndexError then return the None.

# %%
cnf.get_all_spaces(limit=10)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
